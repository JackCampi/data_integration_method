# %% [markdown]
# # Data Integration Methods Survey
#
# Angel ROMERO, Ana María PINZÓN
# Ecole Centrale de Nantes MATHAPPLI

# %%
import numpy as np
import pandas as pd

# %%
folder = r'./Main_Dataset/Classification_datasets/GS-BRCA/Top'

# %%
y_labels = pd.read_csv(f'{folder}/BRCA_label_num.CSV')
X_CNV = pd.read_csv(f'{folder}/BRCA_CNV_top.CSV', index_col= 0)
X_miRNA = pd.read_csv(f'{folder}/BRCA_miRNA_top.CSV', index_col= 0)
X_mRNA = pd.read_csv(f'{folder}/BRCA_mRNA_top.CSV', index_col= 0)
X_Methy = pd.read_csv(f'{folder}/BRCA_Methy_top.CSV', index_col= 0)

# %%
X_CNV = X_CNV.T
X_miRNA = X_miRNA.T
X_mRNA = X_mRNA.T
X_Methy = X_Methy.T

print(f'shape of CNV : {X_CNV.shape}')
print(f'shape of miRNA : {X_miRNA.shape}')
print(f'shape of mRNA : {X_mRNA.shape}')
print(f'shape of X_Menthy : {X_Methy.shape}')
# Out:
# shape of CNV : (671, 5000)
# shape of miRNA : (671, 366)
# shape of mRNA : (671, 5000)
# shape of X_Menthy : (671, 5000)

# %%
y_labels.describe()
# Out:
#             Label
# count  671.000000
# mean     1.268256
# std      1.534535
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      2.000000
# max      4.000000

# %%
X_CNV.describe()
# Out:
#            IVNS1ABP        CELSR3          LIPF         SIDT2        LHFPL4  \
# count  6.710000e+02  6.710000e+02  6.710000e+02  6.710000e+02  6.710000e+02
# mean  -9.000914e-17  2.382595e-17 -2.250228e-17 -2.117862e-17  9.000914e-17
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -3.064481e+00 -4.133347e+00 -6.640694e+00 -3.904073e+00 -3.696738e+00
# 25%   -8.347782e-01 -5.464878e-01 -3.194587e-01 -7.285071e-01 -3.002067e-01
# 50%   -1.749722e-02  3.424230e-01  2.922421e-01  2.258062e-01 -3.099019e-02
# 75%    6.807934e-01  5.869478e-01  4.922921e-01  7.542759e-01  3.409847e-01
# max    3.494888e+00  3.375819e+00  3.873973e+00  2.630033e+00  5.871326e+00
#
#              DHRS7C  ENSG00000263874          ADM2         GSTM2  \
# count  6.710000e+02     6.710000e+02  6.710000e+02  6.710000e+02
# mean  -1.588397e-17     1.588397e-17  7.412517e-17 -3.706259e-17
# std    1.000000e+00     1.000000e+00  1.000000e+00  1.000000e+00
# ...

# %%
X_miRNA.describe()
# Out:
#        hsa.let.7a.1  hsa.let.7a.2  hsa.let.7a.3    hsa.let.7b    hsa.let.7c  \
# count  6.710000e+02  6.710000e+02  6.710000e+02  6.710000e+02  6.710000e+02
# mean  -5.961237e-12 -4.470940e-12  2.086437e-11 -5.961247e-12  1.192250e-11
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -3.803612e+00 -3.785154e+00 -3.792451e+00 -3.509653e+00 -3.136257e+00
# 25%   -6.577967e-01 -6.648204e-01 -6.621095e-01 -6.887117e-01 -6.178110e-01
# 50%    2.982943e-02  1.243990e-02  1.715447e-02  3.636909e-02  7.124856e-02
# 75%    6.485880e-01  6.563217e-01  6.517221e-01  7.402763e-01  6.665029e-01
# max    3.385750e+00  3.386588e+00  3.391250e+00  2.768366e+00  3.169202e+00
#
#          hsa.let.7d    hsa.let.7e  hsa.let.7f.1  hsa.let.7f.2    hsa.let.7g  \
# count  6.710000e+02  6.710000e+02  6.710000e+02  6.710000e+02  6.710000e+02
# mean  -4.470947e-12  4.470938e-12 -5.961250e-12 -1.341282e-11  1.490308e-12
# ...

# %%
X_mRNA.describe()
# Out:
#            C1orf210       GPBP1L1          DEF8         ACSL5           TTN  \
# count  6.710000e+02  6.710000e+02  6.710000e+02  6.710000e+02  6.710000e+02
# mean   1.164824e-16  6.883052e-16 -3.653312e-16 -1.906076e-16  2.117862e-17
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -3.918283e+00 -3.365567e+00 -3.167973e+00 -2.276525e+00 -1.509264e+00
# 25%   -5.644400e-01 -5.798036e-01 -6.782423e-01 -7.935223e-01 -4.991785e-01
# 50%    3.950715e-02  8.763560e-02 -5.430147e-02  1.227651e-02 -1.880889e-01
# 75%    6.905382e-01  6.414753e-01  6.823688e-01  7.369501e-01  1.918539e-01
# max    3.001652e+00  2.978898e+00  2.893079e+00  2.909059e+00  1.014551e+01
#
#        LOC100507424         APPL1          DEXI         MCPH1     WDR86.AS1  \
# count  6.710000e+02  6.710000e+02  6.710000e+02  6.710000e+02  6.710000e+02
# mean   5.288037e-16 -4.235724e-16 -2.488488e-16  2.488488e-16 -4.103358e-17
# ...

# %%
X_Methy.describe()
# Out:
#               WDR46          GFM1         EPHA2         TRPM7          PTH2  \
# count  6.710000e+02  6.710000e+02  6.710000e+02  6.710000e+02  6.710000e+02
# mean  -6.883052e-17  7.941983e-18 -1.270717e-16  1.429557e-16  1.561923e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -2.831268e+00 -8.107571e-01 -2.416639e+00 -1.152077e+00 -1.830949e+00
# 25%   -6.109757e-01 -6.867424e-01 -6.944218e-01 -5.066221e-01 -7.593907e-01
# 50%    2.203066e-02 -5.522467e-01 -1.284692e-01 -2.007578e-01 -1.245130e-01
# 75%    6.371046e-01  6.203672e-01  5.181047e-01  2.373221e-01  6.160662e-01
# max    3.317585e+00  3.661757e+00  4.256149e+00  7.053134e+00  3.229046e+00
#
#                TFAM        PLXDC2         GRIP1     KRTAP20.4         NUP88  \
# count  6.710000e+02  6.710000e+02  6.710000e+02  6.710000e+02  6.710000e+02
# mean   6.353586e-17  6.353586e-17  9.927479e-17 -1.442794e-16 -3.441526e-17
# ...

# %%
X_Methy[1:10]
# Out:
#                     WDR46      GFM1     EPHA2     TRPM7      PTH2      TFAM  \
# TCGA.3C.AALI.01  0.851929 -0.280658 -0.429196  0.489891  0.299657  3.126232
# TCGA.3C.AALJ.01 -0.204287 -0.519341  3.074985  0.142710  1.371165  3.100776
# TCGA.3C.AALK.01  0.644237  1.150601 -0.179217 -0.204742  0.806939  1.984694
# TCGA.5L.AAT0.01  0.059015 -0.529118 -0.177489  0.198645  0.114862  0.913656
# TCGA.5T.A9QA.01 -0.411197 -0.661616 -0.244537  0.817514  2.532036  1.477615
# TCGA.A1.A0SB.01 -1.657192 -0.767863 -2.093386 -0.148226 -1.533666 -0.645547
# TCGA.A1.A0SE.01 -0.931282 -0.521372 -0.042601  0.102580 -0.806540  0.241499
# TCGA.A1.A0SF.01 -0.817070 -0.572948  0.930091 -0.678396  0.263148 -1.869294
# TCGA.A1.A0SG.01 -0.059989  0.179508 -0.387514 -0.490456 -1.162064 -0.916548
#
#                    PLXDC2     GRIP1  KRTAP20.4     NUP88  ...     OR2L2  \
# TCGA.3C.AALI.01 -0.099362  0.605721   0.538895  0.372750  ... -1.449213
# ...
